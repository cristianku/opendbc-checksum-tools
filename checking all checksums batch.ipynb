# %%
# ========================================
# ESTRAZIONE CHECKSUM DA TUTTI I MESSAGGI CON CHECKSUM NEL DBC
# ========================================

import pandas as pd
import cantools
from python.psa_checksum import psa_checksum  # Assumendo che questa libreria sia disponibile nell'ambiente

print("🚀 INIZIO ESTRAZIONE CHECKSUM PER TUTTI I MESSAGGI\n")

# Configurazione
LOG_FILE = 'logs/aa0ad8ba95ff270c|00000017--62c22bb216.csv'  # File di log principale
DBC_FILE = 'dbc/psa_aee2010_r3_fixed2.dbc'  # File DBC

# 1. CARICA DBC
print(f"📂 Carico DBC: {DBC_FILE}...")
try:
    dbc = cantools.database.load_file(DBC_FILE, strict=False)
    print(f"✅ DBC caricato\n")
except FileNotFoundError:
    print(f"❌ File {DBC_FILE} non trovato!")
    exit()

# 2. CARICA CSV (una sola volta, per tutti i messaggi)
print(f"\n📂 Carico CSV: {LOG_FILE}...")
df = pd.read_csv(LOG_FILE)
print(f"✅ Caricato: {len(df)} righe\n")

# 3. TROVA TUTTI I MESSAGGI CON CHECKSUM NEL DBC
messages_with_checksum = []
for msg in dbc.messages:
    checksum_signals = [sig for sig in msg.signals if 'CHECKSUM' in sig.name.upper() or 'CRC' in sig.name.upper()]
    if checksum_signals:
        messages_with_checksum.append((msg, checksum_signals))

print(f"✅ Trovati {len(messages_with_checksum)} messaggi con checksum nel DBC\n")

# 4. CICLO SU OGNI MESSAGGIO CON CHECKSUM
for msg, checksum_signals in messages_with_checksum:
    MESSAGE_ID = msg.frame_id
    
    print("=" * 80)
    print(f"PROCESSO MESSAGGIO 0x{MESSAGE_ID:03X} ({msg.name})")
    print("=" * 80)
    
    # Mostra definizione messaggio
    print(f"Nome: {msg.name}")
    print(f"ID: 0x{MESSAGE_ID:03X} ({MESSAGE_ID})")
    print(f"Lunghezza: {msg.length} bytes")
    print(f"Segnali: {len(msg.signals)}")
    print()
    
    print("📋 SEGNALI NEL MESSAGGIO:")
    print("-" * 80)
    for sig in msg.signals:
        print(f"  {sig.name:30s} | Start: {sig.start:3d} | Length: {sig.length:2d} bit | Scale: {sig.scale} | Offset: {sig.offset}")
        if 'CHECKSUM' in sig.name.upper() or 'CRC' in sig.name.upper():
            print(f"     ⚡ QUESTO È UN CHECKSUM!")
    
    print()
    print(f"✅ Trovati {len(checksum_signals)} checksum:")
    for cs in checksum_signals:
        print(f"   - {cs.name}: bit {cs.start}, lunghezza {cs.length} bit")
    print()
    
    # 5. TROVA IL BUS CORRETTO PER QUESTO MESSAGGIO
    possible_buses = [0, 1, 2, 3]  # Assumi bus possibili (espandi se necessario)
    BUS = None
    df_filtered = None
    for b in possible_buses:
        temp_filtered = df[(df['bus'] == b) & (df['addr'] == f'0x{MESSAGE_ID:x}')].copy()
        if len(temp_filtered) > 0:
            BUS = b
            df_filtered = temp_filtered
            break
    
    if BUS is None:
        print(f"❌ Nessun messaggio trovato per 0x{MESSAGE_ID:03X} su nessun bus!")
        continue
    
    print(f"🔍 Messaggi trovati su bus {BUS}: {len(df_filtered)}")
    print()
    
    # 6. DECODIFICA E ESTRAI CHECKSUM
    print("🔄 Decodifica messaggi ed estrazione checksum...\n")
    
    decoded_messages = []
    for idx, row in df_filtered.iterrows():
        try:
            time = row['time']
            data_hex = row['data']
            
            # Prepara bytes
            if data_hex.startswith('0x'):
                data_hex = data_hex[2:]
            if len(data_hex) % 2:
                data_hex = '0' + data_hex
            data_bytes = bytes.fromhex(data_hex)
            
            # Decodifica
            decoded = dbc.decode_message(MESSAGE_ID, data_bytes)
            
            # Aggiungi info base
            decoded['time'] = time
            decoded['raw_hex'] = data_hex
            decoded['raw_bytes'] = ' '.join([data_hex[i:i+2].upper() for i in range(0, len(data_hex), 2)])
            
            # Verifica TUTTI i checksum
            all_checksums_ok = True
            
            for cs_sig in checksum_signals:
                # Calcola checksum - CREA COPIA FRESCA OGNI VOLTA
                data_array = bytearray(data_bytes)  # Copia fresca per ogni checksum!
                calculated = psa_checksum(MESSAGE_ID, cs_sig, data_array)
                
                # Estrai checksum dal messaggio
                extracted = decoded.get(cs_sig.name, None)
                
                # Converti NamedSignalValue in int
                if hasattr(extracted, 'value'):
                    extracted = int(extracted.value)
                else:
                    extracted = int(extracted) if extracted is not None else 0
                    
                # Verifica
                is_ok = (calculated == extracted)
                all_checksums_ok = all_checksums_ok and is_ok
                
                # Salva con nome univoco per ogni checksum
                decoded[f'{cs_sig.name}_extracted'] = extracted
                decoded[f'{cs_sig.name}_calculated'] = calculated
                decoded[f'{cs_sig.name}_ok'] = is_ok
            
            # Flag globale: OK solo se TUTTI sono OK
            decoded['all_checksums_ok'] = all_checksums_ok
            
            decoded_messages.append(decoded)
            
        except Exception as e:
            print(f"⚠️  Errore decodifica a t={time:.3f}s: {e}")
    
    if not decoded_messages:
        print("❌ Nessun messaggio decodificato!")
        continue
    
    df_decoded = pd.DataFrame(decoded_messages)
    print(f"✅ Decodificati {len(df_decoded)} messaggi\n")
    
    # 7. MOSTRA RISULTATI (simile al codice originale, ma abbreviato per brevità)
    print("=" * 80)
    print("MESSAGGI CON CHECKSUM")
    print("=" * 80)
    print()
    
    N = 5  # Mostra primi 20
    print(f"📋 Primi {N} messaggi:\n")
    
    for idx, row in df_decoded.head(N).iterrows():
        time = row['time']
        raw_bytes = row['raw_bytes']
        all_ok = row['all_checksums_ok']
        
        # Status globale
        status = "✓ OK" if all_ok else "✗ FAIL"
        
        print(f"[{time:8.3f}s] {status:6s} | {raw_bytes}")
        
        # Mostra ogni checksum su riga separata
        for cs in checksum_signals:
            extr_val = row[f'{cs.name}_extracted']
            calc_val = row[f'{cs.name}_calculated']
            
            # Converti in int gestendo NamedSignalValue
            try:
                extr = int(float(extr_val))
            except:
                extr = int(extr_val.value) if hasattr(extr_val, 'value') else int(extr_val)
                
            try:
                calc = int(float(calc_val))
            except:
                calc = int(calc_val.value) if hasattr(calc_val, 'value') else int(calc_val)
            
            ok_symbol = "✓" if row[f'{cs.name}_ok'] else "✗"
            print(f"   {cs.name:30s}: Estratto=0x{extr:X}  Calcolato=0x{calc:X}  [{ok_symbol}]")
        
        # Altri segnali (opzionale, abbreviato)
        print()
    
    # 8. STATISTICHE CHECKSUM (simile al codice originale)
    print(f"\n{'=' * 80}")
    print("📊 STATISTICHE CHECKSUM")
    print("=" * 80)
    
    all_ok_count = df_decoded['all_checksums_ok'].sum()
    all_fail_count = len(df_decoded) - all_ok_count
    
    print(f"Totale messaggi:       {len(df_decoded)}")
    print(f"Tutti checksum OK:     {all_ok_count} ({all_ok_count/len(df_decoded)*100:.1f}%)" if len(df_decoded) > 0 else "N/A")
    print(f"Almeno 1 FAIL:         {all_fail_count} ({all_fail_count/len(df_decoded)*100:.1f}%)" if len(df_decoded) > 0 else "N/A")
    print()
    
    # Statistiche per ogni checksum
    for cs in checksum_signals:
        print(f"--- {cs.name} ---")
        ok_count = df_decoded[f'{cs.name}_ok'].sum()
        fail_count = len(df_decoded) - ok_count
        print(f"  OK:   {ok_count} ({ok_count/len(df_decoded)*100:.1f}%)" if len(df_decoded) > 0 else "N/A")
        print(f"  FAIL: {fail_count} ({fail_count/len(df_decoded)*100:.1f}%)" if len(df_decoded) > 0 else "N/A")
        print()
    
    if all_fail_count > 0:
        print(f"⚠️  Esempi di messaggi con checksum errati (primi 5):")
        fails = df_decoded[~df_decoded['all_checksums_ok']].head(5)
        for idx, row in fails.iterrows():
            print(f"\n   t={row['time']:.3f}s: {row['raw_bytes']}")
            for cs in checksum_signals:
                if not row[f'{cs.name}_ok']:
                    extr_val = row[f'{cs.name}_extracted']
                    calc_val = row[f'{cs.name}_calculated']
                    # Prova diversi modi per convertire
                    try:
                        extr = int(float(extr_val))
                        calc = int(float(calc_val))
                    except:
                        extr = extr_val
                        calc = calc_val
                    print(f"      {cs.name}: Estratto={extr}, Calcolato={calc}")
        print()
    
    # Qui potresti aggiungere il salvataggio CSV per ogni messaggio, simile al codice originale

print("\n🎉 COMPLETATO!")
# Out:
# 🚀 INIZIO ESTRAZIONE CHECKSUM PER TUTTI I MESSAGGI
#
# 📂 Carico DBC: dbc/psa_aee2010_r3_fixed2.dbc...
# ✅ DBC caricato
#
#
# 📂 Carico CSV: logs/aa0ad8ba95ff270c|00000017--62c22bb216.csv...
# ✅ Caricato: 6558620 righe
#
# ✅ Trovati 9 messaggi con checksum nel DBC
#
# ================================================================================
# PROCESSO MESSAGGIO 0x1CD (ESP)
# ================================================================================
# Nome: ESP
# ID: 0x1CD (461)
# Lunghezza: 3 bytes
# Segnali: 5
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   COUNTER                        | Start:   3 | Length:  4 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:   4 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#   ESP_STATUS                     | Start:  15 | Length:  1 bit | Scale: 1 | Offset: 0
#   UNCLEAR                        | Start:  14 | Length: 10 bit | Scale: 1 | Offset: 0
#   ESP_STATUS_INV                 | Start:  20 | Length:  1 bit | Scale: 1 | Offset: 0
#
# ✅ Trovati 1 checksum:
#    - CHECKSUM: bit 4, lunghezza 4 bit
#
# ❌ Nessun messaggio trovato per 0x1CD su nessun bus!
# ================================================================================
# PROCESSO MESSAGGIO 0x2B6 (HS2_DYN1_MDD_ETAT_2B6)
# ================================================================================
# Nome: HS2_DYN1_MDD_ETAT_2B6
# ID: 0x2B6 (694)
# Lunghezza: 8 bytes
# Segnali: 14
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   MDD_DESIRED_DECELERATION       | Start:   7 | Length:  8 bit | Scale: 0.05 | Offset: -10.65
#   MIN_TIME_FOR_DESIRED_GEAR      | Start:  15 | Length:  6 bit | Scale: 0.1 | Offset: 0
#   POTENTIAL_WHEEL_TORQUE_REQUEST | Start:   9 | Length:  2 bit | Scale: 1 | Offset: 0
#   GMP_POTENTIAL_WHEEL_TORQUE     | Start:  23 | Length: 12 bit | Scale: 4 | Offset: -4000
#   ACC_STATUS                     | Start:  27 | Length:  4 bit | Scale: 1 | Offset: 0
#   GMP_WHEEL_TORQUE               | Start:  39 | Length: 14 bit | Scale: 1 | Offset: -4000
#   WHEEL_TORQUE_REQUEST           | Start:  41 | Length:  2 bit | Scale: 1 | Offset: 0
#   PREFILL_REQUEST                | Start:  55 | Length:  1 bit | Scale: 1 | Offset: 0
#   GEAR_TYPE                      | Start:  54 | Length:  1 bit | Scale: 1 | Offset: 0
#   MDD_DECEL_CONTROL_REQ          | Start:  53 | Length:  1 bit | Scale: 1 | Offset: 0
#   MDD_DECEL_TYPE                 | Start:  52 | Length:  2 bit | Scale: 1 | Offset: 0
#   AUTO_BRAKING_STATUS            | Start:  50 | Length:  3 bit | Scale: 1 | Offset: 0
#   DYN_ACC_PROCESS_COUNTER        | Start:  63 | Length:  4 bit | Scale: 1 | Offset: 0
#   DYN_ACC_CHECKSUM               | Start:  59 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#
# ✅ Trovati 1 checksum:
#    - DYN_ACC_CHECKSUM: bit 59, lunghezza 4 bit
#
# 🔍 Messaggi trovati su bus 1: 71831
#
# 🔄 Decodifica messaggi ed estrazione checksum...
#
# ✅ Decodificati 71831 messaggi
#
# ================================================================================
# MESSAGGI CON CHECKSUM
# ================================================================================
#
# 📋 Primi 20 messaggi:
#
# [   0.000s] ✓ OK   | FE 00 00 01 00 00 00 E0
#    DYN_ACC_CHECKSUM              : Estratto=0x0  Calcolato=0x0  [✓]
#
# [   0.020s] ✓ OK   | FE 00 00 01 00 00 40 FB
#    DYN_ACC_CHECKSUM              : Estratto=0xB  Calcolato=0xB  [✓]
#
# [   0.040s] ✓ OK   | FE 00 00 01 00 00 00 0E
#    DYN_ACC_CHECKSUM              : Estratto=0xE  Calcolato=0xE  [✓]
#
# [   0.060s] ✓ OK   | FE 00 00 01 00 00 40 19
#    DYN_ACC_CHECKSUM              : Estratto=0x9  Calcolato=0x9  [✓]
#
# [   0.080s] ✓ OK   | FE 00 00 01 00 00 00 2C
#    DYN_ACC_CHECKSUM              : Estratto=0xC  Calcolato=0xC  [✓]
#
# [   0.100s] ✓ OK   | FE 00 00 02 00 00 43 33
#    DYN_ACC_CHECKSUM              : Estratto=0x3  Calcolato=0x3  [✓]
#
# [   0.120s] ✓ OK   | FE 00 00 02 00 00 03 46
#    DYN_ACC_CHECKSUM              : Estratto=0x6  Calcolato=0x6  [✓]
#
# [   0.140s] ✓ OK   | FE 00 00 02 00 00 43 51
#    DYN_ACC_CHECKSUM              : Estratto=0x1  Calcolato=0x1  [✓]
#
# [   0.160s] ✓ OK   | FE 00 00 02 00 00 03 64
#    DYN_ACC_CHECKSUM              : Estratto=0x4  Calcolato=0x4  [✓]
#
# [   0.180s] ✓ OK   | FE 00 00 02 00 00 43 7F
#    DYN_ACC_CHECKSUM              : Estratto=0xF  Calcolato=0xF  [✓]
#
# [   0.200s] ✓ OK   | FE 00 00 02 00 00 03 82
#    DYN_ACC_CHECKSUM              : Estratto=0x2  Calcolato=0x2  [✓]
#
# [   0.220s] ✓ OK   | FE 00 00 02 00 00 43 9D
#    DYN_ACC_CHECKSUM              : Estratto=0xD  Calcolato=0xD  [✓]
#
# [   0.240s] ✓ OK   | FE 00 00 02 00 00 03 A0
#    DYN_ACC_CHECKSUM              : Estratto=0x0  Calcolato=0x0  [✓]
#
# [   0.260s] ✓ OK   | FE 00 00 02 00 00 43 BB
#    DYN_ACC_CHECKSUM              : Estratto=0xB  Calcolato=0xB  [✓]
#
# [   0.280s] ✓ OK   | FE 00 00 02 00 00 03 CE
#    DYN_ACC_CHECKSUM              : Estratto=0xE  Calcolato=0xE  [✓]
#
# [   0.300s] ✓ OK   | FE 00 00 02 00 00 43 D9
#    DYN_ACC_CHECKSUM              : Estratto=0x9  Calcolato=0x9  [✓]
#
# [   0.320s] ✓ OK   | FE 00 00 02 00 00 03 EC
#    DYN_ACC_CHECKSUM              : Estratto=0xC  Calcolato=0xC  [✓]
#
# [   0.340s] ✓ OK   | FE 00 00 02 00 00 43 F7
#    DYN_ACC_CHECKSUM              : Estratto=0x7  Calcolato=0x7  [✓]
#
# [   0.360s] ✓ OK   | FE 00 00 02 00 00 03 0A
#    DYN_ACC_CHECKSUM              : Estratto=0xA  Calcolato=0xA  [✓]
#
# [   0.380s] ✓ OK   | FE 00 00 02 00 00 43 15
#    DYN_ACC_CHECKSUM              : Estratto=0x5  Calcolato=0x5  [✓]
#
#
# ================================================================================
# 📊 STATISTICHE CHECKSUM
# ================================================================================
# Totale messaggi:       71831
# Tutti checksum OK:     71831 (100.0%)
# Almeno 1 FAIL:         0 (0.0%)
#
# --- DYN_ACC_CHECKSUM ---
#   OK:   71831 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESSO MESSAGGIO 0x2F5 (STEERING)
# ================================================================================
# Nome: STEERING
# ID: 0x2F5 (757)
# Lunghezza: 7 bytes
# Segnali: 6
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   CHECKSUM                       | Start:   7 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#   COUNTER                        | Start:   3 | Length:  4 bit | Scale: 1 | Offset: 0
#   DRIVER_TORQUE                  | Start:  15 | Length:  8 bit | Scale: 1 | Offset: 0
#   ANGLE                          | Start:  31 | Length: 16 bit | Scale: 0.1 | Offset: 0
#   RATE                           | Start:  47 | Length: 12 bit | Scale: 1 | Offset: 0
#   NEW_SIGNAL_1                   | Start:  48 | Length:  1 bit | Scale: 1 | Offset: 0
#
# ✅ Trovati 1 checksum:
#    - CHECKSUM: bit 7, lunghezza 4 bit
#
# 🔍 Messaggi trovati su bus 0: 143593
#
# 🔄 Decodifica messaggi ed estrazione checksum...
#
# ✅ Decodificati 143593 messaggi
#
# ================================================================================
# MESSAGGI CON CHECKSUM
# ================================================================================
#
# 📋 Primi 20 messaggi:
#
# [   0.000s] ✓ OK   | 15 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x1  Calcolato=0x1  [✓]
#
# [   0.010s] ✓ OK   | 06 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x0  [✓]
#
# [   0.020s] ✓ OK   | F7 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0xF  Calcolato=0xF  [✓]
#
# [   0.030s] ✓ OK   | E8 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0xE  Calcolato=0xE  [✓]
#
# [   0.040s] ✓ OK   | D9 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0xD  Calcolato=0xD  [✓]
#
# [   0.050s] ✓ OK   | CA 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0xC  Calcolato=0xC  [✓]
#
# [   0.060s] ✓ OK   | BB 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0xB  Calcolato=0xB  [✓]
#
# [   0.070s] ✓ OK   | AC 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0xA  Calcolato=0xA  [✓]
#
# [   0.080s] ✓ OK   | 9D 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x9  Calcolato=0x9  [✓]
#
# [   0.090s] ✓ OK   | 8E 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x8  Calcolato=0x8  [✓]
#
# [   0.100s] ✓ OK   | 7F 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x7  Calcolato=0x7  [✓]
#
# [   0.110s] ✓ OK   | 60 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x6  Calcolato=0x6  [✓]
#
# [   0.120s] ✓ OK   | 51 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x5  Calcolato=0x5  [✓]
#
# [   0.130s] ✓ OK   | 42 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x4  Calcolato=0x4  [✓]
#
# [   0.140s] ✓ OK   | 33 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x3  Calcolato=0x3  [✓]
#
# [   0.150s] ✓ OK   | 24 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x2  Calcolato=0x2  [✓]
#
# [   0.160s] ✓ OK   | 15 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x1  Calcolato=0x1  [✓]
#
# [   0.170s] ✓ OK   | 06 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x0  [✓]
#
# [   0.180s] ✓ OK   | F7 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0xF  Calcolato=0xF  [✓]
#
# [   0.190s] ✓ OK   | E8 00 00 7F FF 00 01
#    CHECKSUM                      : Estratto=0xE  Calcolato=0xE  [✓]
#
#
# ================================================================================
# 📊 STATISTICHE CHECKSUM
# ================================================================================
# Totale messaggi:       143593
# Tutti checksum OK:     143593 (100.0%)
# Almeno 1 FAIL:         0 (0.0%)
#
# --- CHECKSUM ---
#   OK:   143593 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESSO MESSAGGIO 0x2F6 (HS2_DYN_MDD_ETAT_2F6)
# ================================================================================
# Nome: HS2_DYN_MDD_ETAT_2F6
# ID: 0x2F6 (758)
# Lunghezza: 8 bytes
# Segnali: 17
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   REQ_HAPTIC_COLL_ALERT_ARC      | Start:   7 | Length:  1 bit | Scale: 1 | Offset: 0
#   REQ_AUDIO_COLL_ALERT_ARC       | Start:   6 | Length:  1 bit | Scale: 1 | Offset: 0
#   REQ_VISUAL_COLL_ALERT_ARC      | Start:   5 | Length:  1 bit | Scale: 1 | Offset: 0
#   BLIND_SENSOR                   | Start:   4 | Length:  1 bit | Scale: 1 | Offset: 0
#   REQUEST_TAKEOVER               | Start:   2 | Length:  2 bit | Scale: 1 | Offset: 0
#   TARGET_DETECTED                | Start:   0 | Length:  1 bit | Scale: 1 | Offset: 0
#   INTER_VEHICLE_DISTANCE         | Start:  15 | Length: 10 bit | Scale: 0.25 | Offset: 0
#   AEB_ENABLED                    | Start:  21 | Length:  1 bit | Scale: 1 | Offset: 0
#   AUTO_BRAKING_IN_PROGRESS       | Start:  20 | Length:  1 bit | Scale: 1 | Offset: 0
#   ARC_STATUS                     | Start:  19 | Length:  4 bit | Scale: 1 | Offset: 0
#   DISPLAY_INTERVEHICLE_TIME      | Start:  39 | Length:  6 bit | Scale: 0.1 | Offset: 0
#   DRIVE_AWAY_REQUEST             | Start:  33 | Length:  1 bit | Scale: 1 | Offset: 0
#   AUTO_BRAKING_STATUS            | Start:  47 | Length:  3 bit | Scale: 1 | Offset: 0
#   MDD_DECEL_CONTROL_REQ          | Start:  42 | Length:  1 bit | Scale: 1 | Offset: 0
#   PROCESS_COUNTER_4B_ACC2        | Start:  55 | Length:  4 bit | Scale: 1 | Offset: 0
#   CHECKSUM_TRANSM_DYN_ACC2       | Start:  51 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#   TARGET_POSITION                | Start:  63 | Length:  3 bit | Scale: 1 | Offset: 0
#
# ✅ Trovati 1 checksum:
#    - CHECKSUM_TRANSM_DYN_ACC2: bit 51, lunghezza 4 bit
#
# 🔍 Messaggi trovati su bus 1: 71831
#
# 🔄 Decodifica messaggi ed estrazione checksum...
#
# ✅ Decodificati 71831 messaggi
#
# ================================================================================
# MESSAGGI CON CHECKSUM
# ================================================================================
#
# 📋 Primi 20 messaggi:
#
# [   0.000s] ✓ OK   | 00 FF 80 00 F8 00 ED 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xD  Calcolato=0xD  [✓]
#
# [   0.020s] ✓ OK   | 00 FF 80 00 F8 00 FC 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xC  Calcolato=0xC  [✓]
#
# [   0.040s] ✓ OK   | 00 FF 80 00 F8 00 0B 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xB  Calcolato=0xB  [✓]
#
# [   0.060s] ✓ OK   | 00 FF 80 00 F8 00 1A 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xA  Calcolato=0xA  [✓]
#
# [   0.080s] ✓ OK   | 00 FF 86 00 F8 60 2D 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xD  Calcolato=0xD  [✓]
#
# [   0.100s] ✓ OK   | 00 FF 86 00 F8 60 3C 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xC  Calcolato=0xC  [✓]
#
# [   0.120s] ✓ OK   | 00 FF 86 00 F8 60 4B 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xB  Calcolato=0xB  [✓]
#
# [   0.140s] ✓ OK   | 00 FF 86 00 F8 60 5A 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xA  Calcolato=0xA  [✓]
#
# [   0.160s] ✓ OK   | 00 FF 86 00 F8 60 69 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x9  Calcolato=0x9  [✓]
#
# [   0.180s] ✓ OK   | 00 FF 86 00 F8 60 78 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x8  Calcolato=0x8  [✓]
#
# [   0.200s] ✓ OK   | 00 FF 86 00 F8 60 87 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x7  Calcolato=0x7  [✓]
#
# [   0.220s] ✓ OK   | 00 FF 86 00 F8 60 96 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x6  Calcolato=0x6  [✓]
#
# [   0.240s] ✓ OK   | 00 FF 86 00 F8 60 A5 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x5  Calcolato=0x5  [✓]
#
# [   0.260s] ✓ OK   | 00 FF 86 00 F8 60 B4 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x4  Calcolato=0x4  [✓]
#
# [   0.280s] ✓ OK   | 00 FF 86 00 F8 60 C3 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x3  Calcolato=0x3  [✓]
#
# [   0.300s] ✓ OK   | 00 FF 86 00 F8 60 D2 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x2  Calcolato=0x2  [✓]
#
# [   0.320s] ✓ OK   | 00 FF 86 00 F8 60 E1 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x1  Calcolato=0x1  [✓]
#
# [   0.340s] ✓ OK   | 00 FF 86 00 F8 60 F0 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0x0  Calcolato=0x0  [✓]
#
# [   0.360s] ✓ OK   | 00 FF 86 00 F8 60 0F 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xF  Calcolato=0xF  [✓]
#
# [   0.380s] ✓ OK   | 00 FF 86 00 F8 60 1E 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Estratto=0xE  Calcolato=0xE  [✓]
#
#
# ================================================================================
# 📊 STATISTICHE CHECKSUM
# ================================================================================
# Totale messaggi:       71831
# Tutti checksum OK:     71831 (100.0%)
# Almeno 1 FAIL:         0 (0.0%)
#
# --- CHECKSUM_TRANSM_DYN_ACC2 ---
#   OK:   71831 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESSO MESSAGGIO 0x305 (STEERING_ALT)
# ================================================================================
# Nome: STEERING_ALT
# ID: 0x305 (773)
# Lunghezza: 7 bytes
# Segnali: 6
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   ANGLE                          | Start:   7 | Length: 16 bit | Scale: 0.1 | Offset: 0
#   RATE                           | Start:  23 | Length:  8 bit | Scale: 1 | Offset: 0
#   RATE_SIGN                      | Start:  31 | Length:  1 bit | Scale: 1 | Offset: 0
#   x_CHECKSUM                     | Start:  39 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#   x_COUNTER                      | Start:  35 | Length:  4 bit | Scale: 1 | Offset: 0
#   RATE_ALT                       | Start:  47 | Length:  8 bit | Scale: 1 | Offset: 0
#
# ✅ Trovati 1 checksum:
#    - x_CHECKSUM: bit 39, lunghezza 4 bit
#
# 🔍 Messaggi trovati su bus 0: 143660
#
# 🔄 Decodifica messaggi ed estrazione checksum...
#
# ✅ Decodificati 143660 messaggi
#
# ================================================================================
# MESSAGGI CON CHECKSUM
# ================================================================================
#
# 📋 Primi 20 messaggi:
#
# [   0.000s] ✗ FAIL | FF A2 00 07 5A 00 20
#    x_CHECKSUM                    : Estratto=0x5  Calcolato=0xE  [✗]
#
# [   0.010s] ✗ FAIL | FF A2 00 07 4B 00 20
#    x_CHECKSUM                    : Estratto=0x4  Calcolato=0xD  [✗]
#
# [   0.020s] ✗ FAIL | FF A2 00 07 3C 00 20
#    x_CHECKSUM                    : Estratto=0x3  Calcolato=0xC  [✗]
#
# [   0.030s] ✗ FAIL | FF A2 00 07 2D 00 20
#    x_CHECKSUM                    : Estratto=0x2  Calcolato=0xB  [✗]
#
# [   0.040s] ✗ FAIL | FF A2 00 07 1E 00 20
#    x_CHECKSUM                    : Estratto=0x1  Calcolato=0xA  [✗]
#
# [   0.050s] ✗ FAIL | FF A2 00 07 0F 00 20
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x9  [✗]
#
# [   0.060s] ✗ FAIL | FF A2 00 07 F0 00 20
#    x_CHECKSUM                    : Estratto=0xF  Calcolato=0x8  [✗]
#
# [   0.070s] ✗ FAIL | FF A2 00 07 E1 00 20
#    x_CHECKSUM                    : Estratto=0xE  Calcolato=0x7  [✗]
#
# [   0.080s] ✗ FAIL | FF A2 00 07 D2 00 20
#    x_CHECKSUM                    : Estratto=0xD  Calcolato=0x6  [✗]
#
# [   0.090s] ✗ FAIL | FF A2 00 07 C3 00 20
#    x_CHECKSUM                    : Estratto=0xC  Calcolato=0x5  [✗]
#
# [   0.100s] ✗ FAIL | FF A2 00 07 B4 00 20
#    x_CHECKSUM                    : Estratto=0xB  Calcolato=0x4  [✗]
#
# [   0.110s] ✗ FAIL | FF A2 00 07 A5 00 20
#    x_CHECKSUM                    : Estratto=0xA  Calcolato=0x3  [✗]
#
# [   0.120s] ✗ FAIL | FF A2 00 07 96 00 20
#    x_CHECKSUM                    : Estratto=0x9  Calcolato=0x2  [✗]
#
# [   0.130s] ✗ FAIL | FF A2 00 07 87 00 20
#    x_CHECKSUM                    : Estratto=0x8  Calcolato=0x1  [✗]
#
# [   0.140s] ✗ FAIL | FF A2 00 07 78 00 20
#    x_CHECKSUM                    : Estratto=0x7  Calcolato=0x0  [✗]
#
# [   0.150s] ✗ FAIL | FF A2 00 07 69 00 20
#    x_CHECKSUM                    : Estratto=0x6  Calcolato=0xF  [✗]
#
# [   0.160s] ✗ FAIL | FF A2 00 07 5A 00 20
#    x_CHECKSUM                    : Estratto=0x5  Calcolato=0xE  [✗]
#
# [   0.170s] ✗ FAIL | FF A2 00 07 4B 00 20
#    x_CHECKSUM                    : Estratto=0x4  Calcolato=0xD  [✗]
#
# [   0.180s] ✗ FAIL | FF A2 00 07 3C 00 20
#    x_CHECKSUM                    : Estratto=0x3  Calcolato=0xC  [✗]
#
# [   0.190s] ✗ FAIL | FF A2 00 07 2D 00 20
#    x_CHECKSUM                    : Estratto=0x2  Calcolato=0xB  [✗]
#
#
# ================================================================================
# 📊 STATISTICHE CHECKSUM
# ================================================================================
# Totale messaggi:       143660
# Tutti checksum OK:     2137 (1.5%)
# Almeno 1 FAIL:         141523 (98.5%)
#
# --- x_CHECKSUM ---
#   OK:   2137 (1.5%)
#   FAIL: 141523 (98.5%)
#
# ⚠️  Esempi di messaggi con checksum errati (primi 5):
#
#    t=0.000s: FF A2 00 07 5A 00 20
#       x_CHECKSUM: Estratto=5, Calcolato=14
#
#    t=0.010s: FF A2 00 07 4B 00 20
#       x_CHECKSUM: Estratto=4, Calcolato=13
#
#    t=0.020s: FF A2 00 07 3C 00 20
#       x_CHECKSUM: Estratto=3, Calcolato=12
#
#    t=0.030s: FF A2 00 07 2D 00 20
#       x_CHECKSUM: Estratto=2, Calcolato=11
#
#    t=0.040s: FF A2 00 07 1E 00 20
#       x_CHECKSUM: Estratto=1, Calcolato=10
#
# ================================================================================
# PROCESSO MESSAGGIO 0x3AD (Dyn_EasyMove)
# ================================================================================
# Nome: Dyn_EasyMove
# ID: 0x3AD (941)
# Lunghezza: 8 bytes
# Segnali: 2
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   P299_Com_bCrCtlInhib           | Start:  17 | Length:  1 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#   P337_Com_stPrkBrk              | Start:  24 | Length:  3 bit | Scale: 1 | Offset: 0
#
# ✅ Trovati 1 checksum:
#    - P299_Com_bCrCtlInhib: bit 17, lunghezza 1 bit
#
# 🔍 Messaggi trovati su bus 0: 71828
#
# 🔄 Decodifica messaggi ed estrazione checksum...
#
# ✅ Decodificati 71828 messaggi
#
# ================================================================================
# MESSAGGI CON CHECKSUM
# ================================================================================
#
# 📋 Primi 20 messaggi:
#
# [   0.000s] ✗ FAIL | 50 00 00 01 7F 22 00 85
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.020s] ✗ FAIL | 50 00 00 01 7F 42 00 92
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.040s] ✗ FAIL | 50 00 00 01 7F 42 00 A1
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.060s] ✗ FAIL | 50 00 00 01 7F 52 00 BF
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.080s] ✗ FAIL | 50 00 00 01 7F 42 00 CF
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.100s] ✗ FAIL | 50 00 00 01 7F 22 00 D0
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.120s] ✗ FAIL | 50 00 00 01 7F 42 00 ED
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.140s] ✗ FAIL | 50 00 00 01 7F 52 00 FB
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.160s] ✗ FAIL | 50 00 00 01 7F 42 00 0B
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.180s] ✗ FAIL | 50 00 00 01 7F 52 00 19
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.200s] ✗ FAIL | 50 00 00 01 7F 52 00 28
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.220s] ✗ FAIL | 50 00 00 01 7F 02 00 3C
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.240s] ✗ FAIL | 50 00 00 01 7F 02 00 4B
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.260s] ✗ FAIL | 50 00 00 01 7F 42 00 56
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.280s] ✗ FAIL | 50 00 00 01 7F 92 00 60
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.300s] ✗ FAIL | 50 00 00 01 7F B2 00 7D
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.320s] ✗ FAIL | 50 00 00 01 7E A2 00 8E
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.340s] ✗ FAIL | 50 00 00 01 7E A2 00 9D
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.360s] ✗ FAIL | 50 00 00 01 7F 52 00 A0
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
# [   0.380s] ✗ FAIL | 50 00 00 01 7F F2 00 B5
#    P299_Com_bCrCtlInhib          : Estratto=0x0  Calcolato=0xE  [✗]
#
#
# ================================================================================
# 📊 STATISTICHE CHECKSUM
# ================================================================================
# Totale messaggi:       71828
# Tutti checksum OK:     0 (0.0%)
# Almeno 1 FAIL:         71828 (100.0%)
#
# --- P299_Com_bCrCtlInhib ---
#   OK:   0 (0.0%)
#   FAIL: 71828 (100.0%)
#
# ⚠️  Esempi di messaggi con checksum errati (primi 5):
#
#    t=0.000s: 50 00 00 01 7F 22 00 85
#       P299_Com_bCrCtlInhib: Estratto=0, Calcolato=14
#
#    t=0.020s: 50 00 00 01 7F 42 00 92
#       P299_Com_bCrCtlInhib: Estratto=0, Calcolato=14
#
#    t=0.040s: 50 00 00 01 7F 42 00 A1
#       P299_Com_bCrCtlInhib: Estratto=0, Calcolato=14
#
#    t=0.060s: 50 00 00 01 7F 52 00 BF
#       P299_Com_bCrCtlInhib: Estratto=0, Calcolato=14
#
#    t=0.080s: 50 00 00 01 7F 42 00 CF
#       P299_Com_bCrCtlInhib: Estratto=0, Calcolato=14
#
# ================================================================================
# PROCESSO MESSAGGIO 0x3F2 (LANE_KEEP_ASSIST)
# ================================================================================
# Nome: LANE_KEEP_ASSIST
# ID: 0x3F2 (1010)
# Lunghezza: 8 bytes
# Segnali: 11
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   DRIVE                          | Start:   6 | Length:  1 bit | Scale: 1 | Offset: 0
#   x_CHECKSUM                     | Start:  15 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#   x_COUNTER                      | Start:  11 | Length:  4 bit | Scale: 1 | Offset: 0
#   unknown2                       | Start:  23 | Length:  8 bit | Scale: 1 | Offset: 0
#   TORQUE                         | Start:  31 | Length: 11 bit | Scale: 1 | Offset: 0
#   STATUS                         | Start:  36 | Length:  3 bit | Scale: 1 | Offset: 0
#   LANE_DEPARTURE                 | Start:  33 | Length:  2 bit | Scale: 1 | Offset: 0
#   TORQUE_FACTOR                  | Start:  47 | Length:  7 bit | Scale: 1 | Offset: 0
#   LXA_ACTIVATION                 | Start:  40 | Length:  1 bit | Scale: 1 | Offset: 0
#   SET_ANGLE                      | Start:  55 | Length: 14 bit | Scale: 0.1 | Offset: 0
#   unknown4                       | Start:  57 | Length:  1 bit | Scale: 1 | Offset: 0
#
# ✅ Trovati 1 checksum:
#    - x_CHECKSUM: bit 15, lunghezza 4 bit
#
# 🔍 Messaggi trovati su bus 0: 71
#
# 🔄 Decodifica messaggi ed estrazione checksum...
#
# ✅ Decodificati 71 messaggi
#
# ================================================================================
# MESSAGGI CON CHECKSUM
# ================================================================================
#
# 📋 Primi 20 messaggi:
#
# [   0.030s] ✗ FAIL | 00 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x7  [✗]
#
# [   0.080s] ✗ FAIL | 00 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x7  [✗]
#
# [   0.130s] ✗ FAIL | 00 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x7  [✗]
#
# [   0.180s] ✗ FAIL | 00 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x7  [✗]
#
# [   0.230s] ✗ FAIL | 00 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x7  [✗]
#
# [   0.280s] ✗ FAIL | 00 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x7  [✗]
#
# [   0.320s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.340s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.380s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.430s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.480s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.530s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.580s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.629s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.680s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.730s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.780s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.830s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.880s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
# [   0.930s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    x_CHECKSUM                    : Estratto=0x0  Calcolato=0x6  [✗]
#
#
# ================================================================================
# 📊 STATISTICHE CHECKSUM
# ================================================================================
# Totale messaggi:       71
# Tutti checksum OK:     0 (0.0%)
# Almeno 1 FAIL:         71 (100.0%)
#
# --- x_CHECKSUM ---
#   OK:   0 (0.0%)
#   FAIL: 71 (100.0%)
#
# ⚠️  Esempi di messaggi con checksum errati (primi 5):
#
#    t=0.030s: 00 00 00 00 04 00 00 00
#       x_CHECKSUM: Estratto=0, Calcolato=7
#
#    t=0.080s: 00 00 00 00 04 00 00 00
#       x_CHECKSUM: Estratto=0, Calcolato=7
#
#    t=0.130s: 00 00 00 00 04 00 00 00
#       x_CHECKSUM: Estratto=0, Calcolato=7
#
#    t=0.180s: 00 00 00 00 04 00 00 00
#       x_CHECKSUM: Estratto=0, Calcolato=7
#
#    t=0.230s: 00 00 00 00 04 00 00 00
#       x_CHECKSUM: Estratto=0, Calcolato=7
#
# ================================================================================
# PROCESSO MESSAGGIO 0x42D (NEW_MSG_42D)
# ================================================================================
# Nome: NEW_MSG_42D
# ID: 0x42D (1069)
# Lunghezza: 4 bytes
# Segnali: 3
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   COUNTER                        | Start:  16 | Length:  4 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:  20 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#   ACC_RELATED                    | Start:  31 | Length:  8 bit | Scale: 1 | Offset: 0
#
# ✅ Trovati 1 checksum:
#    - CHECKSUM: bit 20, lunghezza 4 bit
#
# 🔍 Messaggi trovati su bus 0: 28732
#
# 🔄 Decodifica messaggi ed estrazione checksum...
#
# ✅ Decodificati 28732 messaggi
#
# ================================================================================
# MESSAGGI CON CHECKSUM
# ================================================================================
#
# 📋 Primi 20 messaggi:
#
# [   0.010s] ✓ OK   | FE 00 87 00
#    CHECKSUM                      : Estratto=0x8  Calcolato=0x8  [✓]
#
# [   0.060s] ✓ OK   | FE 00 78 00
#    CHECKSUM                      : Estratto=0x7  Calcolato=0x7  [✓]
#
# [   0.110s] ✓ OK   | FE 00 69 00
#    CHECKSUM                      : Estratto=0x6  Calcolato=0x6  [✓]
#
# [   0.160s] ✓ OK   | FE 00 5A 00
#    CHECKSUM                      : Estratto=0x5  Calcolato=0x5  [✓]
#
# [   0.210s] ✓ OK   | FE 00 4B 00
#    CHECKSUM                      : Estratto=0x4  Calcolato=0x4  [✓]
#
# [   0.260s] ✓ OK   | FE 00 3C 00
#    CHECKSUM                      : Estratto=0x3  Calcolato=0x3  [✓]
#
# [   0.310s] ✓ OK   | FE 00 2D 00
#    CHECKSUM                      : Estratto=0x2  Calcolato=0x2  [✓]
#
# [   0.360s] ✓ OK   | FE 00 1E 00
#    CHECKSUM                      : Estratto=0x1  Calcolato=0x1  [✓]
#
# [   0.410s] ✓ OK   | FE 00 0F 00
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x0  [✓]
#
# [   0.460s] ✓ OK   | FE 00 F0 00
#    CHECKSUM                      : Estratto=0xF  Calcolato=0xF  [✓]
#
# [   0.510s] ✓ OK   | FE 00 E1 00
#    CHECKSUM                      : Estratto=0xE  Calcolato=0xE  [✓]
#
# [   0.560s] ✓ OK   | FE 00 D2 00
#    CHECKSUM                      : Estratto=0xD  Calcolato=0xD  [✓]
#
# [   0.610s] ✓ OK   | FE 00 C3 00
#    CHECKSUM                      : Estratto=0xC  Calcolato=0xC  [✓]
#
# [   0.660s] ✓ OK   | FE 00 B4 00
#    CHECKSUM                      : Estratto=0xB  Calcolato=0xB  [✓]
#
# [   0.710s] ✓ OK   | FE 00 A5 00
#    CHECKSUM                      : Estratto=0xA  Calcolato=0xA  [✓]
#
# [   0.760s] ✓ OK   | FE 00 96 00
#    CHECKSUM                      : Estratto=0x9  Calcolato=0x9  [✓]
#
# [   0.809s] ✓ OK   | FE 00 87 00
#    CHECKSUM                      : Estratto=0x8  Calcolato=0x8  [✓]
#
# [   0.860s] ✓ OK   | FE 00 78 00
#    CHECKSUM                      : Estratto=0x7  Calcolato=0x7  [✓]
#
# [   0.910s] ✓ OK   | FE 00 69 00
#    CHECKSUM                      : Estratto=0x6  Calcolato=0x6  [✓]
#
# [   0.960s] ✓ OK   | FE 00 5A 00
#    CHECKSUM                      : Estratto=0x5  Calcolato=0x5  [✓]
#
#
# ================================================================================
# 📊 STATISTICHE CHECKSUM
# ================================================================================
# Totale messaggi:       28732
# Tutti checksum OK:     28732 (100.0%)
# Almeno 1 FAIL:         0 (0.0%)
#
# --- CHECKSUM ---
#   OK:   28732 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESSO MESSAGGIO 0x452 (HS2_DAT_MDD_CMD_452)
# ================================================================================
# Nome: HS2_DAT_MDD_CMD_452
# ID: 0x452 (1106)
# Lunghezza: 6 bytes
# Segnali: 17
#
# 📋 SEGNALI NEL MESSAGGIO:
# --------------------------------------------------------------------------------
#   FRONT_WIPER_STATUS             | Start:   7 | Length:  2 bit | Scale: 1 | Offset: 0
#   TURN_SIGNAL_STATUS             | Start:   5 | Length:  2 bit | Scale: 1 | Offset: 0
#   LONGITUDINAL_REGULATION_TYPE   | Start:   1 | Length:  2 bit | Scale: 1 | Offset: 0
#   SPEED_SETPOINT                 | Start:  15 | Length:  8 bit | Scale: 1 | Offset: 0
#   RVV_ACC_ACTIVATION_REQ         | Start:  23 | Length:  1 bit | Scale: 1 | Offset: 0
#   LVV_ACTIVATION_REQ             | Start:  22 | Length:  1 bit | Scale: 1 | Offset: 0
#   BRAKE_ONLY_CMD_BSI             | Start:  18 | Length:  1 bit | Scale: 1 | Offset: 0
#   CHECKSUM_CONS_RVV_LVV2         | Start:  17 | Length:  2 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#   COUNTER                        | Start:  31 | Length:  4 bit | Scale: 1 | Offset: 0
#   ARC_HABIT_ACTIVATION_REQ       | Start:  27 | Length:  1 bit | Scale: 1 | Offset: 0
#   ARC_HABIT_SENSITIVITY          | Start:  26 | Length:  3 bit | Scale: 1 | Offset: 0
#   INTER_VEHICLE_TIME_SETPOINT    | Start:  39 | Length:  6 bit | Scale: 0.1 | Offset: 0
#   FORCE_ACTIVATION_HAB_CMD       | Start:  33 | Length:  1 bit | Scale: 1 | Offset: 0
#   FRONT_WASH_STATUS              | Start:  32 | Length:  1 bit | Scale: 1 | Offset: 0
#   ACC_PROGRAM_MODE               | Start:  47 | Length:  2 bit | Scale: 1 | Offset: 0
#   COCKPIT_GO_ACC_REQUEST         | Start:  45 | Length:  1 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:  43 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ QUESTO È UN CHECKSUM!
#
# ✅ Trovati 2 checksum:
#    - CHECKSUM_CONS_RVV_LVV2: bit 17, lunghezza 2 bit
#    - CHECKSUM: bit 43, lunghezza 4 bit
#
# 🔍 Messaggi trovati su bus 0: 67
#
# 🔄 Decodifica messaggi ed estrazione checksum...
#
# ✅ Decodificati 67 messaggi
#
# ================================================================================
# MESSAGGI CON CHECKSUM
# ================================================================================
#
# 📋 Primi 20 messaggi:
#
# [   0.040s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.090s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.140s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.190s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.240s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.290s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.340s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.390s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.440s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.490s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.540s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.590s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.640s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.690s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.740s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.790s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.840s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.890s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.940s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
# [   0.989s] ✗ FAIL | 00 00 00 02 00 00
#    CHECKSUM_CONS_RVV_LVV2        : Estratto=0x0  Calcolato=0x0  [✓]
#    CHECKSUM                      : Estratto=0x0  Calcolato=0x2  [✗]
#
#
# ================================================================================
# 📊 STATISTICHE CHECKSUM
# ================================================================================
# Totale messaggi:       67
# Tutti checksum OK:     0 (0.0%)
# Almeno 1 FAIL:         67 (100.0%)
#
# --- CHECKSUM_CONS_RVV_LVV2 ---
#   OK:   67 (100.0%)
#   FAIL: 0 (0.0%)
#
# --- CHECKSUM ---
#   OK:   0 (0.0%)
#   FAIL: 67 (100.0%)
#
# ⚠️  Esempi di messaggi con checksum errati (primi 5):
#
#    t=0.040s: 00 00 00 02 00 00
#       CHECKSUM: Estratto=0, Calcolato=2
#
#    t=0.090s: 00 00 00 02 00 00
#       CHECKSUM: Estratto=0, Calcolato=2
#
#    t=0.140s: 00 00 00 02 00 00
#       CHECKSUM: Estratto=0, Calcolato=2
#
#    t=0.190s: 00 00 00 02 00 00
#       CHECKSUM: Estratto=0, Calcolato=2
#
#    t=0.240s: 00 00 00 02 00 00
#       CHECKSUM: Estratto=0, Calcolato=2
#
#
# 🎉 COMPLETATO!
