# %%
# ========================================
# EXTRACT CHECKSUMS FROM ALL MESSAGES WITH CHECKSUM IN DBC
# ========================================

import pandas as pd
import cantools
from python.psa_checksum import psa_checksum  # Assuming this library is available in the environment

print("🚀 START CHECKSUM EXTRACTION FOR ALL MESSAGES\n")

# Configuration
# LOG_FILE = 'logs/aa0ad8ba95ff270c|00000017--62c22bb216.csv'  # Main log file
#LOG_FILE = 'logs/6a7075a4fdd765ee|0000004e--1f612006dd.csv'
LOG_FILE = 'logs/sunny1.csv'

DBC_FILE = 'dbc/psa_aee2010_r3.dbc'  # DBC file

# 1. LOAD DBC
print(f"📂 Loading DBC: {DBC_FILE}...")
try:
    dbc = cantools.database.load_file(DBC_FILE, strict=False)
    print(f"✅ DBC loaded\n")
except FileNotFoundError:
    print(f"❌ File {DBC_FILE} not found!")
    exit()

# 2. LOAD CSV (once, for all messages)
print(f"\n📂 Loading CSV: {LOG_FILE}...")
df = pd.read_csv(LOG_FILE)
print(f"✅ Loaded: {len(df)} rows\n")

# 3. FIND ALL MESSAGES WITH CHECKSUM IN DBC
messages_with_checksum = []
for msg in dbc.messages:
    checksum_signals = [sig for sig in msg.signals if 'CHECKSUM' in sig.name.upper() or 'CRC' in sig.name.upper()]
    if checksum_signals:
        messages_with_checksum.append((msg, checksum_signals))

print(f"✅ Found {len(messages_with_checksum)} messages with checksum in DBC\n")

# Initialize global statistics
global_stats = {
    'total_message_types': 0,
    'total_messages_analyzed': 0,
    'total_messages_ok': 0,
    'total_messages_fail': 0,
    'details_per_message': []
}

# 4. LOOP THROUGH EACH MESSAGE WITH CHECKSUM
for msg, checksum_signals in messages_with_checksum:
    MESSAGE_ID = msg.frame_id
    
    print("=" * 80)
    print(f"PROCESS MESSAGE 0x{MESSAGE_ID:03X} ({msg.name})")
    print("=" * 80)
    
    # Show message definition
    print(f"Name: {msg.name}")
    print(f"ID: 0x{MESSAGE_ID:03X} ({MESSAGE_ID})")
    print(f"Length: {msg.length} bytes")
    print(f"Signals: {len(msg.signals)}")
    print()
    
    print("📋 SIGNALS IN MESSAGE:")
    print("-" * 80)
    for sig in msg.signals:
        print(f"  {sig.name:30s} | Start: {sig.start:3d} | Length: {sig.length:2d} bit | Scale: {sig.scale} | Offset: {sig.offset}")
        if 'CHECKSUM' in sig.name.upper() or 'CRC' in sig.name.upper():
            print(f"     ⚡ THIS IS A CHECKSUM!")
    
    print()
    print(f"✅ Found {len(checksum_signals)} checksum:")
    for cs in checksum_signals:
        print(f"   - {cs.name}: bit {cs.start}, length {cs.length} bit")
    print()
    
    # 5. FIND THE CORRECT BUS FOR THIS MESSAGE
    # Special case: HS2_DAT_MDD_CMD_452 must use only bus 1
    if msg.name == "HS2_DAT_MDD_CMD_452":
        print(f"⚠️  Special message {msg.name}: forced use of bus 1")
        possible_buses = [1]  # Only bus 1 for this message
    else:
        possible_buses = [0, 1, 2, 3]  # Assume possible buses (expand if needed)
    
    BUS = None
    df_filtered = None
    for b in possible_buses:
        temp_filtered = df[(df['bus'] == b) & (df['addr'] == f'0x{MESSAGE_ID:x}')].copy()
        if len(temp_filtered) > 0:
            BUS = b
            df_filtered = temp_filtered
            break
    
    if BUS is None:
        print(f"❌ No message found for 0x{MESSAGE_ID:03X} on any bus!")
        continue
    
    print(f"🔍 Messages found on bus {BUS}: {len(df_filtered)}")
    print()
    
    # 6. DECODE AND EXTRACT CHECKSUM
    print("🔄 Decoding messages and extracting checksum...\n")
    
    decoded_messages = []
    for idx, row in df_filtered.iterrows():
        try:
            time = row['time']
            data_hex = row['data']
            
            # Prepare bytes
            if data_hex.startswith('0x'):
                data_hex = data_hex[2:]
            if len(data_hex) % 2:
                data_hex = '0' + data_hex
            data_bytes = bytes.fromhex(data_hex)
            
            # Decode
            decoded = dbc.decode_message(MESSAGE_ID, data_bytes)
            
            # Add basic info
            decoded['time'] = time
            decoded['raw_hex'] = data_hex
            decoded['raw_bytes'] = ' '.join([data_hex[i:i+2].upper() for i in range(0, len(data_hex), 2)])
            
            # Verify ALL checksums
            all_checksums_ok = True
            
            for cs_sig in checksum_signals:
                # Calculate checksum - CREATE FRESH COPY EVERY TIME
                data_array = bytearray(data_bytes)  # Fresh copy for each checksum!
                calculated = psa_checksum(MESSAGE_ID, cs_sig, data_array)
                
                # Extract checksum from message
                extracted = decoded.get(cs_sig.name, None)
                
                # Convert NamedSignalValue to int
                if hasattr(extracted, 'value'):
                    extracted = int(extracted.value)
                else:
                    extracted = int(extracted) if extracted is not None else 0
                    
                # Verify
                is_ok = (calculated == extracted)
                all_checksums_ok = all_checksums_ok and is_ok
                
                # Save with unique name for each checksum
                decoded[f'{cs_sig.name}_extracted'] = extracted
                decoded[f'{cs_sig.name}_calculated'] = calculated
                decoded[f'{cs_sig.name}_ok'] = is_ok
            
            # Global flag: OK only if ALL are OK
            decoded['all_checksums_ok'] = all_checksums_ok
            
            decoded_messages.append(decoded)
            
        except Exception as e:
            print(f"⚠️  Decode error at t={time:.3f}s: {e}")
    
    if not decoded_messages:
        print("❌ No messages decoded!")
        continue
    
    df_decoded = pd.DataFrame(decoded_messages)
    print(f"✅ Decoded {len(df_decoded)} messages\n")
    
    # 7. SHOW RESULTS (similar to original code, but abbreviated for brevity)
    print("=" * 80)
    print("MESSAGES WITH CHECKSUM")
    print("=" * 80)
    print()
    
    N = 5  # Show first 5
    print(f"📋 First {N} messages:\n")
    
    for idx, row in df_decoded.head(N).iterrows():
        time = row['time']
        raw_bytes = row['raw_bytes']
        all_ok = row['all_checksums_ok']
        
        # Global status
        status = "✓ OK" if all_ok else "✗ FAIL"
        
        print(f"[{time:8.3f}s] {status:6s} | {raw_bytes}")
        
        # Show each checksum on separate line
        for cs in checksum_signals:
            extr_val = row[f'{cs.name}_extracted']
            calc_val = row[f'{cs.name}_calculated']
            
            # Convert to int handling NamedSignalValue
            try:
                extr = int(float(extr_val))
            except:
                extr = int(extr_val.value) if hasattr(extr_val, 'value') else int(extr_val)
                
            try:
                calc = int(float(calc_val))
            except:
                calc = int(calc_val.value) if hasattr(calc_val, 'value') else int(calc_val)
            
            ok_symbol = "✓" if row[f'{cs.name}_ok'] else "✗"
            print(f"   {cs.name:30s}: Extracted=0x{extr:X}  Calculated=0x{calc:X}  [{ok_symbol}]")
        
        # Other signals (optional, abbreviated)
        print()
    
    # 8. CHECKSUM STATISTICS (similar to original code)
    print(f"\n{'=' * 80}")
    print("📊 CHECKSUM STATISTICS")
    print("=" * 80)
    
    all_ok_count = df_decoded['all_checksums_ok'].sum()
    all_fail_count = len(df_decoded) - all_ok_count
    
    print(f"Total messages:        {len(df_decoded)}")
    print(f"All checksums OK:      {all_ok_count} ({all_ok_count/len(df_decoded)*100:.1f}%)" if len(df_decoded) > 0 else "N/A")
    print(f"At least 1 FAIL:       {all_fail_count} ({all_fail_count/len(df_decoded)*100:.1f}%)" if len(df_decoded) > 0 else "N/A")
    print()
    
    # Statistics for each checksum
    for cs in checksum_signals:
        print(f"--- {cs.name} ---")
        ok_count = df_decoded[f'{cs.name}_ok'].sum()
        fail_count = len(df_decoded) - ok_count
        print(f"  OK:   {ok_count} ({ok_count/len(df_decoded)*100:.1f}%)" if len(df_decoded) > 0 else "N/A")
        print(f"  FAIL: {fail_count} ({fail_count/len(df_decoded)*100:.1f}%)" if len(df_decoded) > 0 else "N/A")
        print()
    
    if all_fail_count > 0:
        print(f"⚠️  Examples of messages with wrong checksums (first 5):")
        fails = df_decoded[~df_decoded['all_checksums_ok']].head(5)
        for idx, row in fails.iterrows():
            print(f"\n   t={row['time']:.3f}s: {row['raw_bytes']}")
            for cs in checksum_signals:
                if not row[f'{cs.name}_ok']:
                    extr_val = row[f'{cs.name}_extracted']
                    calc_val = row[f'{cs.name}_calculated']
                    # Try different ways to convert
                    try:
                        extr = int(float(extr_val))
                        calc = int(float(calc_val))
                    except:
                        extr = extr_val
                        calc = calc_val
                    print(f"      {cs.name}: Extracted={extr}, Calculated={calc}")
        print()
    
    # Update global statistics
    global_stats['total_message_types'] += 1
    global_stats['total_messages_analyzed'] += len(df_decoded)
    global_stats['total_messages_ok'] += all_ok_count
    global_stats['total_messages_fail'] += all_fail_count
    
    global_stats['details_per_message'].append({
        'message_id': f"0x{MESSAGE_ID:03X}",
        'message_name': msg.name,
        'bus': BUS,
        'total': len(df_decoded),
        'ok': all_ok_count,
        'fail': all_fail_count,
        'success_rate': (all_ok_count/len(df_decoded)*100) if len(df_decoded) > 0 else 0
    })
# Out:
# 🚀 START CHECKSUM EXTRACTION FOR ALL MESSAGES
#
# 📂 Loading DBC: dbc/psa_aee2010_r3.dbc...
# ✅ DBC loaded
#
#
# 📂 Loading CSV: logs/sunny1.csv...
# ✅ Loaded: 854684 rows
#
# ✅ Found 10 messages with checksum in DBC
#
# ================================================================================
# PROCESS MESSAGE 0x1CD (ESP)
# ================================================================================
# Name: ESP
# ID: 0x1CD (461)
# Length: 3 bytes
# Signals: 5
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   COUNTER                        | Start:   3 | Length:  4 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:   4 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   ESP_STATUS                     | Start:  15 | Length:  1 bit | Scale: 1 | Offset: 0
#   UNCLEAR                        | Start:  14 | Length: 10 bit | Scale: 1 | Offset: 0
#   ESP_STATUS_INV                 | Start:  20 | Length:  1 bit | Scale: 1 | Offset: 0
#
# ✅ Found 1 checksum:
#    - CHECKSUM: bit 4, length 4 bit
#
# ❌ No message found for 0x1CD on any bus!
# ================================================================================
# PROCESS MESSAGE 0x2B6 (HS2_DYN1_MDD_ETAT_2B6)
# ================================================================================
# Name: HS2_DYN1_MDD_ETAT_2B6
# ID: 0x2B6 (694)
# Length: 8 bytes
# Signals: 14
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   MDD_DESIRED_DECELERATION       | Start:   7 | Length:  8 bit | Scale: 0.05 | Offset: -10.65
#   MIN_TIME_FOR_DESIRED_GEAR      | Start:  15 | Length:  6 bit | Scale: 0.1 | Offset: 0
#   POTENTIAL_WHEEL_TORQUE_REQUEST | Start:   9 | Length:  2 bit | Scale: 1 | Offset: 0
#   GMP_POTENTIAL_WHEEL_TORQUE     | Start:  23 | Length: 12 bit | Scale: 4 | Offset: -4000
#   ACC_STATUS                     | Start:  27 | Length:  4 bit | Scale: 1 | Offset: 0
#   GMP_WHEEL_TORQUE               | Start:  39 | Length: 14 bit | Scale: 1 | Offset: -4000
#   WHEEL_TORQUE_REQUEST           | Start:  41 | Length:  2 bit | Scale: 1 | Offset: 0
#   PREFILL_REQUEST                | Start:  55 | Length:  1 bit | Scale: 1 | Offset: 0
#   GEAR_TYPE                      | Start:  54 | Length:  1 bit | Scale: 1 | Offset: 0
#   MDD_DECEL_CONTROL_REQ          | Start:  53 | Length:  1 bit | Scale: 1 | Offset: 0
#   MDD_DECEL_TYPE                 | Start:  52 | Length:  2 bit | Scale: 1 | Offset: 0
#   AUTO_BRAKING_STATUS            | Start:  50 | Length:  3 bit | Scale: 1 | Offset: 0
#   DYN_ACC_PROCESS_COUNTER        | Start:  63 | Length:  4 bit | Scale: 1 | Offset: 0
#   DYN_ACC_CHECKSUM               | Start:  59 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#
# ✅ Found 1 checksum:
#    - DYN_ACC_CHECKSUM: bit 59, length 4 bit
#
# 🔍 Messages found on bus 1: 9448
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 9448 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.000s] ✓ OK   | FE 00 00 02 00 00 43 7F
#    DYN_ACC_CHECKSUM              : Extracted=0xF  Calculated=0xF  [✓]
#
# [   0.020s] ✓ OK   | FE 00 00 02 00 00 03 82
#    DYN_ACC_CHECKSUM              : Extracted=0x2  Calculated=0x2  [✓]
#
# [   0.040s] ✓ OK   | FE 00 00 02 00 00 43 9D
#    DYN_ACC_CHECKSUM              : Extracted=0xD  Calculated=0xD  [✓]
#
# [   0.060s] ✓ OK   | FE 00 00 02 00 00 03 A0
#    DYN_ACC_CHECKSUM              : Extracted=0x0  Calculated=0x0  [✓]
#
# [   0.080s] ✓ OK   | FE 00 00 02 00 00 43 BB
#    DYN_ACC_CHECKSUM              : Extracted=0xB  Calculated=0xB  [✓]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        9448
# All checksums OK:      9448 (100.0%)
# At least 1 FAIL:       0 (0.0%)
#
# --- DYN_ACC_CHECKSUM ---
#   OK:   9448 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESS MESSAGE 0x2F5 (STEERING)
# ================================================================================
# Name: STEERING
# ID: 0x2F5 (757)
# Length: 7 bytes
# Signals: 6
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   CHECKSUM                       | Start:   7 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   COUNTER                        | Start:   3 | Length:  4 bit | Scale: 1 | Offset: 0
#   DRIVER_TORQUE                  | Start:  15 | Length:  8 bit | Scale: 1 | Offset: 0
#   ANGLE                          | Start:  31 | Length: 16 bit | Scale: 0.1 | Offset: 0
#   RATE                           | Start:  47 | Length: 12 bit | Scale: 1 | Offset: 0
#   NEW_SIGNAL_1                   | Start:  48 | Length:  1 bit | Scale: 1 | Offset: 0
#
# ✅ Found 1 checksum:
#    - CHECKSUM: bit 7, length 4 bit
#
# 🔍 Messages found on bus 0: 18964
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 18964 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.000s] ✓ OK   | 15 00 00 7F FF 00 01
#    CHECKSUM                      : Extracted=0x1  Calculated=0x1  [✓]
#
# [   0.010s] ✓ OK   | 06 00 00 7F FF 00 01
#    CHECKSUM                      : Extracted=0x0  Calculated=0x0  [✓]
#
# [   0.020s] ✓ OK   | F7 00 00 7F FF 00 01
#    CHECKSUM                      : Extracted=0xF  Calculated=0xF  [✓]
#
# [   0.030s] ✓ OK   | E8 00 00 7F FF 00 01
#    CHECKSUM                      : Extracted=0xE  Calculated=0xE  [✓]
#
# [   0.040s] ✓ OK   | F9 FF 00 7F FF 00 01
#    CHECKSUM                      : Extracted=0xF  Calculated=0xF  [✓]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        18964
# All checksums OK:      18964 (100.0%)
# At least 1 FAIL:       0 (0.0%)
#
# --- CHECKSUM ---
#   OK:   18964 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESS MESSAGE 0x2F6 (HS2_DYN_MDD_ETAT_2F6)
# ================================================================================
# Name: HS2_DYN_MDD_ETAT_2F6
# ID: 0x2F6 (758)
# Length: 8 bytes
# Signals: 17
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   REQ_HAPTIC_COLL_ALERT_ARC      | Start:   7 | Length:  1 bit | Scale: 1 | Offset: 0
#   REQ_AUDIO_COLL_ALERT_ARC       | Start:   6 | Length:  1 bit | Scale: 1 | Offset: 0
#   REQ_VISUAL_COLL_ALERT_ARC      | Start:   5 | Length:  1 bit | Scale: 1 | Offset: 0
#   BLIND_SENSOR                   | Start:   4 | Length:  1 bit | Scale: 1 | Offset: 0
#   REQUEST_TAKEOVER               | Start:   2 | Length:  2 bit | Scale: 1 | Offset: 0
#   TARGET_DETECTED                | Start:   0 | Length:  1 bit | Scale: 1 | Offset: 0
#   INTER_VEHICLE_DISTANCE         | Start:  15 | Length: 10 bit | Scale: 0.25 | Offset: 0
#   AEB_ENABLED                    | Start:  21 | Length:  1 bit | Scale: 1 | Offset: 0
#   AUTO_BRAKING_IN_PROGRESS       | Start:  20 | Length:  1 bit | Scale: 1 | Offset: 0
#   ARC_STATUS                     | Start:  19 | Length:  4 bit | Scale: 1 | Offset: 0
#   DISPLAY_INTERVEHICLE_TIME      | Start:  39 | Length:  6 bit | Scale: 0.1 | Offset: 0
#   DRIVE_AWAY_REQUEST             | Start:  33 | Length:  1 bit | Scale: 1 | Offset: 0
#   AUTO_BRAKING_STATUS            | Start:  47 | Length:  3 bit | Scale: 1 | Offset: 0
#   MDD_DECEL_CONTROL_REQ          | Start:  42 | Length:  1 bit | Scale: 1 | Offset: 0
#   PROCESS_COUNTER_4B_ACC2        | Start:  55 | Length:  4 bit | Scale: 1 | Offset: 0
#   CHECKSUM_TRANSM_DYN_ACC2       | Start:  51 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   TARGET_POSITION                | Start:  63 | Length:  3 bit | Scale: 1 | Offset: 0
#
# ✅ Found 1 checksum:
#    - CHECKSUM_TRANSM_DYN_ACC2: bit 51, length 4 bit
#
# 🔍 Messages found on bus 1: 9447
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 9447 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.010s] ✓ OK   | 00 FF 86 00 F8 60 78 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Extracted=0x8  Calculated=0x8  [✓]
#
# [   0.030s] ✓ OK   | 00 FF 86 00 F8 60 87 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Extracted=0x7  Calculated=0x7  [✓]
#
# [   0.050s] ✓ OK   | 00 FF 86 00 F8 60 96 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Extracted=0x6  Calculated=0x6  [✓]
#
# [   0.070s] ✓ OK   | 00 FF 86 00 F8 60 A5 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Extracted=0x5  Calculated=0x5  [✓]
#
# [   0.090s] ✓ OK   | 00 FF 86 00 F8 60 B4 00
#    CHECKSUM_TRANSM_DYN_ACC2      : Extracted=0x4  Calculated=0x4  [✓]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        9447
# All checksums OK:      9447 (100.0%)
# At least 1 FAIL:       0 (0.0%)
#
# --- CHECKSUM_TRANSM_DYN_ACC2 ---
#   OK:   9447 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESS MESSAGE 0x305 (STEERING_ALT)
# ================================================================================
# Name: STEERING_ALT
# ID: 0x305 (773)
# Length: 7 bytes
# Signals: 6
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   ANGLE                          | Start:   7 | Length: 16 bit | Scale: 0.1 | Offset: 0
#   RATE                           | Start:  23 | Length:  8 bit | Scale: 1 | Offset: 0
#   RATE_SIGN                      | Start:  31 | Length:  1 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:  39 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   COUNTER                        | Start:  35 | Length:  4 bit | Scale: 1 | Offset: 0
#   RATE_ALT                       | Start:  47 | Length:  8 bit | Scale: 1 | Offset: 0
#
# ✅ Found 1 checksum:
#    - CHECKSUM: bit 39, length 4 bit
#
# 🔍 Messages found on bus 0: 18893
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 18893 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.000s] ✓ OK   | 08 10 00 87 CA 00 20
#    CHECKSUM                      : Extracted=0xC  Calculated=0xC  [✓]
#
# [   0.010s] ✓ OK   | 08 10 00 07 5B 00 20
#    CHECKSUM                      : Extracted=0x5  Calculated=0x5  [✓]
#
# [   0.020s] ✓ OK   | 08 10 00 87 AC 00 20
#    CHECKSUM                      : Extracted=0xA  Calculated=0xA  [✓]
#
# [   0.030s] ✓ OK   | 08 10 00 87 BD 00 20
#    CHECKSUM                      : Extracted=0xB  Calculated=0xB  [✓]
#
# [   0.040s] ✓ OK   | 08 10 00 07 0E 00 20
#    CHECKSUM                      : Extracted=0x0  Calculated=0x0  [✓]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        18893
# All checksums OK:      18893 (100.0%)
# At least 1 FAIL:       0 (0.0%)
#
# --- CHECKSUM ---
#   OK:   18893 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESS MESSAGE 0x38D (HS2_DYN_ABR_38D)
# ================================================================================
# Name: HS2_DYN_ABR_38D
# ID: 0x38D (909)
# Length: 8 bytes
# Signals: 15
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   VITESSE_VEHICULE_ROUES         | Start:   7 | Length: 16 bit | Scale: 0.01 | Offset: 0
#   DISTANCE_ROUES                 | Start:  23 | Length: 16 bit | Scale: 0.1 | Offset: 0
#   P052_Com_aLng                  | Start:  32 | Length:  8 bit | Scale: 0.08 | Offset: -14
#   ACCEL_LONGI_ROUES              | Start:  39 | Length:  8 bit | Scale: 0.08 | Offset: -14
#   COUNTER                        | Start:  47 | Length:  4 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:  43 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   REQ_LAMPE_WARNING              | Start:  55 | Length:  1 bit | Scale: 1 | Offset: 0
#   AUTOR_ARRET_HILL_STT           | Start:  54 | Length:  1 bit | Scale: 1 | Offset: 0
#   SENS_ROULAGE                   | Start:  53 | Length:  2 bit | Scale: 1 | Offset: 0
#   VVH_INDISP                     | Start:  51 | Length:  2 bit | Scale: 1 | Offset: 0
#   VHL_MVT                        | Start:  49 | Length:  2 bit | Scale: 1 | Offset: 0
#   HADC_CLUTCH_CONDITION          | Start:  63 | Length:  2 bit | Scale: 1 | Offset: 0
#   HADC_SPEED_CONDITION           | Start:  61 | Length:  1 bit | Scale: 1 | Offset: 0
#   HADC_STATUS                    | Start:  60 | Length:  2 bit | Scale: 1 | Offset: 0
#   HADC_FAULTY                    | Start:  58 | Length:  2 bit | Scale: 1 | Offset: 0
#
# ✅ Found 1 checksum:
#    - CHECKSUM: bit 43, length 4 bit
#
# 🔍 Messages found on bus 0: 4741
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 4741 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.030s] ✓ OK   | 00 00 84 19 AF 2C 46 00
#    CHECKSUM                      : Extracted=0xC  Calculated=0xC  [✓]
#
# [   0.070s] ✓ OK   | 00 00 84 19 AF 3B 46 00
#    CHECKSUM                      : Extracted=0xB  Calculated=0xB  [✓]
#
# [   0.110s] ✓ OK   | 00 00 84 19 AF 4A 46 00
#    CHECKSUM                      : Extracted=0xA  Calculated=0xA  [✓]
#
# [   0.150s] ✓ OK   | 00 00 84 19 AF 59 46 00
#    CHECKSUM                      : Extracted=0x9  Calculated=0x9  [✓]
#
# [   0.190s] ✓ OK   | 00 00 84 19 AF 68 46 00
#    CHECKSUM                      : Extracted=0x8  Calculated=0x8  [✓]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        4741
# All checksums OK:      4741 (100.0%)
# At least 1 FAIL:       0 (0.0%)
#
# --- CHECKSUM ---
#   OK:   4741 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESS MESSAGE 0x3AD (Dyn_EasyMove)
# ================================================================================
# Name: Dyn_EasyMove
# ID: 0x3AD (941)
# Length: 8 bytes
# Signals: 2
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   P299_Com_bCrCtlInhib           | Start:  17 | Length:  1 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   P337_Com_stPrkBrk              | Start:  24 | Length:  3 bit | Scale: 1 | Offset: 0
#
# ✅ Found 1 checksum:
#    - P299_Com_bCrCtlInhib: bit 17, length 1 bit
#
# 🔍 Messages found on bus 0: 9483
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 9483 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.000s] ✗ FAIL | 50 00 00 01 7F 52 00 37
#    P299_Com_bCrCtlInhib          : Extracted=0x0  Calculated=0xE  [✗]
#
# [   0.020s] ✗ FAIL | 50 00 00 01 7E 82 00 44
#    P299_Com_bCrCtlInhib          : Extracted=0x0  Calculated=0xE  [✗]
#
# [   0.040s] ✗ FAIL | 50 00 00 01 7E 82 00 53
#    P299_Com_bCrCtlInhib          : Extracted=0x0  Calculated=0xE  [✗]
#
# [   0.060s] ✗ FAIL | 50 00 00 01 7F 12 00 68
#    P299_Com_bCrCtlInhib          : Extracted=0x0  Calculated=0xE  [✗]
#
# [   0.080s] ✗ FAIL | 50 00 00 01 7F 52 00 73
#    P299_Com_bCrCtlInhib          : Extracted=0x0  Calculated=0xE  [✗]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        9483
# All checksums OK:      0 (0.0%)
# At least 1 FAIL:       9483 (100.0%)
#
# --- P299_Com_bCrCtlInhib ---
#   OK:   0 (0.0%)
#   FAIL: 9483 (100.0%)
#
# ⚠️  Examples of messages with wrong checksums (first 5):
#
#    t=0.000s: 50 00 00 01 7F 52 00 37
#       P299_Com_bCrCtlInhib: Extracted=0, Calculated=14
#
#    t=0.020s: 50 00 00 01 7E 82 00 44
#       P299_Com_bCrCtlInhib: Extracted=0, Calculated=14
#
#    t=0.040s: 50 00 00 01 7E 82 00 53
#       P299_Com_bCrCtlInhib: Extracted=0, Calculated=14
#
#    t=0.060s: 50 00 00 01 7F 12 00 68
#       P299_Com_bCrCtlInhib: Extracted=0, Calculated=14
#
#    t=0.080s: 50 00 00 01 7F 52 00 73
#       P299_Com_bCrCtlInhib: Extracted=0, Calculated=14
#
# ================================================================================
# PROCESS MESSAGE 0x3F2 (LANE_KEEP_ASSIST)
# ================================================================================
# Name: LANE_KEEP_ASSIST
# ID: 0x3F2 (1010)
# Length: 8 bytes
# Signals: 11
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   DRIVE                          | Start:   6 | Length:  1 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:  15 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   COUNTER                        | Start:  11 | Length:  4 bit | Scale: 1 | Offset: 0
#   unknown2                       | Start:  23 | Length:  8 bit | Scale: 1 | Offset: 0
#   TORQUE                         | Start:  31 | Length: 11 bit | Scale: 1 | Offset: 0
#   STATUS                         | Start:  36 | Length:  3 bit | Scale: 1 | Offset: 0
#   LANE_DEPARTURE                 | Start:  33 | Length:  2 bit | Scale: 1 | Offset: 0
#   TORQUE_FACTOR                  | Start:  47 | Length:  7 bit | Scale: 1 | Offset: 0
#   LXA_ACTIVATION                 | Start:  40 | Length:  1 bit | Scale: 1 | Offset: 0
#   SET_ANGLE                      | Start:  55 | Length: 14 bit | Scale: 0.1 | Offset: 0
#   unknown4                       | Start:  57 | Length:  1 bit | Scale: 1 | Offset: 0
#
# ✅ Found 1 checksum:
#    - CHECKSUM: bit 15, length 4 bit
#
# 🔍 Messages found on bus 0: 146
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 146 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.020s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    CHECKSUM                      : Extracted=0x0  Calculated=0x6  [✗]
#
# [   0.040s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    CHECKSUM                      : Extracted=0x0  Calculated=0x6  [✗]
#
# [   0.080s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    CHECKSUM                      : Extracted=0x0  Calculated=0x6  [✗]
#
# [   0.130s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    CHECKSUM                      : Extracted=0x0  Calculated=0x6  [✗]
#
# [   0.180s] ✗ FAIL | 10 00 00 00 04 00 00 00
#    CHECKSUM                      : Extracted=0x0  Calculated=0x6  [✗]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        146
# All checksums OK:      0 (0.0%)
# At least 1 FAIL:       146 (100.0%)
#
# --- CHECKSUM ---
#   OK:   0 (0.0%)
#   FAIL: 146 (100.0%)
#
# ⚠️  Examples of messages with wrong checksums (first 5):
#
#    t=0.020s: 10 00 00 00 04 00 00 00
#       CHECKSUM: Extracted=0, Calculated=6
#
#    t=0.040s: 10 00 00 00 04 00 00 00
#       CHECKSUM: Extracted=0, Calculated=6
#
#    t=0.080s: 10 00 00 00 04 00 00 00
#       CHECKSUM: Extracted=0, Calculated=6
#
#    t=0.130s: 10 00 00 00 04 00 00 00
#       CHECKSUM: Extracted=0, Calculated=6
#
#    t=0.180s: 10 00 00 00 04 00 00 00
#       CHECKSUM: Extracted=0, Calculated=6
#
# ================================================================================
# PROCESS MESSAGE 0x42D (NEW_MSG_42D)
# ================================================================================
# Name: NEW_MSG_42D
# ID: 0x42D (1069)
# Length: 4 bytes
# Signals: 3
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   COUNTER                        | Start:  16 | Length:  4 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:  20 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   ACC_RELATED                    | Start:  31 | Length:  8 bit | Scale: 1 | Offset: 0
#
# ✅ Found 1 checksum:
#    - CHECKSUM: bit 20, length 4 bit
#
# 🔍 Messages found on bus 0: 3793
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 3793 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.040s] ✓ OK   | FE 00 3C 00
#    CHECKSUM                      : Extracted=0x3  Calculated=0x3  [✓]
#
# [   0.090s] ✓ OK   | FE 00 2D 00
#    CHECKSUM                      : Extracted=0x2  Calculated=0x2  [✓]
#
# [   0.140s] ✓ OK   | FE 00 1E 00
#    CHECKSUM                      : Extracted=0x1  Calculated=0x1  [✓]
#
# [   0.190s] ✓ OK   | FE 00 0F 00
#    CHECKSUM                      : Extracted=0x0  Calculated=0x0  [✓]
#
# [   0.240s] ✓ OK   | FE 00 F0 00
#    CHECKSUM                      : Extracted=0xF  Calculated=0xF  [✓]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        3793
# All checksums OK:      3793 (100.0%)
# At least 1 FAIL:       0 (0.0%)
#
# --- CHECKSUM ---
#   OK:   3793 (100.0%)
#   FAIL: 0 (0.0%)
#
# ================================================================================
# PROCESS MESSAGE 0x452 (HS2_DAT_MDD_CMD_452)
# ================================================================================
# Name: HS2_DAT_MDD_CMD_452
# ID: 0x452 (1106)
# Length: 6 bytes
# Signals: 17
#
# 📋 SIGNALS IN MESSAGE:
# --------------------------------------------------------------------------------
#   FRONT_WIPER_STATUS             | Start:   7 | Length:  2 bit | Scale: 1 | Offset: 0
#   TURN_SIGNAL_STATUS             | Start:   5 | Length:  2 bit | Scale: 1 | Offset: 0
#   LONGITUDINAL_REGULATION_TYPE   | Start:   1 | Length:  2 bit | Scale: 1 | Offset: 0
#   SPEED_SETPOINT                 | Start:  15 | Length:  8 bit | Scale: 1 | Offset: 0
#   RVV_ACC_ACTIVATION_REQ         | Start:  23 | Length:  1 bit | Scale: 1 | Offset: 0
#   LVV_ACTIVATION_REQ             | Start:  22 | Length:  1 bit | Scale: 1 | Offset: 0
#   BRAKE_ONLY_CMD_BSI             | Start:  18 | Length:  1 bit | Scale: 1 | Offset: 0
#   CHECKSUM_CONS_RVV_LVV2         | Start:  17 | Length:  2 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#   COUNTER                        | Start:  31 | Length:  4 bit | Scale: 1 | Offset: 0
#   ARC_HABIT_ACTIVATION_REQ       | Start:  27 | Length:  1 bit | Scale: 1 | Offset: 0
#   ARC_HABIT_SENSITIVITY          | Start:  26 | Length:  3 bit | Scale: 1 | Offset: 0
#   INTER_VEHICLE_TIME_SETPOINT    | Start:  39 | Length:  6 bit | Scale: 0.1 | Offset: 0
#   FORCE_ACTIVATION_HAB_CMD       | Start:  33 | Length:  1 bit | Scale: 1 | Offset: 0
#   FRONT_WASH_STATUS              | Start:  32 | Length:  1 bit | Scale: 1 | Offset: 0
#   ACC_PROGRAM_MODE               | Start:  47 | Length:  2 bit | Scale: 1 | Offset: 0
#   COCKPIT_GO_ACC_REQUEST         | Start:  45 | Length:  1 bit | Scale: 1 | Offset: 0
#   CHECKSUM                       | Start:  43 | Length:  4 bit | Scale: 1 | Offset: 0
#      ⚡ THIS IS A CHECKSUM!
#
# ✅ Found 2 checksum:
#    - CHECKSUM_CONS_RVV_LVV2: bit 17, length 2 bit
#    - CHECKSUM: bit 43, length 4 bit
#
# ⚠️  Special message HS2_DAT_MDD_CMD_452: forced use of bus 1
# 🔍 Messages found on bus 1: 3794
#
# 🔄 Decoding messages and extracting checksum...
#
# ✅ Decoded 3794 messages
#
# ================================================================================
# MESSAGES WITH CHECKSUM
# ================================================================================
#
# 📋 First 5 messages:
#
# [   0.000s] ✓ OK   | 00 FF 00 A2 F8 03
#    CHECKSUM_CONS_RVV_LVV2        : Extracted=0x0  Calculated=0x0  [✓]
#    CHECKSUM                      : Extracted=0x3  Calculated=0x3  [✓]
#
# [   0.050s] ✓ OK   | 00 FF 00 B2 F8 02
#    CHECKSUM_CONS_RVV_LVV2        : Extracted=0x0  Calculated=0x0  [✓]
#    CHECKSUM                      : Extracted=0x2  Calculated=0x2  [✓]
#
# [   0.100s] ✓ OK   | 00 FF 00 C2 F8 01
#    CHECKSUM_CONS_RVV_LVV2        : Extracted=0x0  Calculated=0x0  [✓]
#    CHECKSUM                      : Extracted=0x1  Calculated=0x1  [✓]
#
# [   0.150s] ✓ OK   | 00 FF 00 D2 F8 00
#    CHECKSUM_CONS_RVV_LVV2        : Extracted=0x0  Calculated=0x0  [✓]
#    CHECKSUM                      : Extracted=0x0  Calculated=0x0  [✓]
#
# [   0.200s] ✓ OK   | 00 FF 00 E2 F8 0F
#    CHECKSUM_CONS_RVV_LVV2        : Extracted=0x0  Calculated=0x0  [✓]
#    CHECKSUM                      : Extracted=0xF  Calculated=0xF  [✓]
#
#
# ================================================================================
# 📊 CHECKSUM STATISTICS
# ================================================================================
# Total messages:        3794
# All checksums OK:      3794 (100.0%)
# At least 1 FAIL:       0 (0.0%)
#
# --- CHECKSUM_CONS_RVV_LVV2 ---
#   OK:   3794 (100.0%)
#   FAIL: 0 (0.0%)
#
# --- CHECKSUM ---
#   OK:   3794 (100.0%)
#   FAIL: 0 (0.0%)

# %%
# ========================================
# FINAL AGGREGATE STATISTICS
# ========================================
print("\n\n")
print("=" * 100)
print("🏁 FINAL STATISTICS - COMPLETE SUMMARY")
print("=" * 100)
print()

print(f"📊 OVERALL TOTALS:")
print(f"   Message types analyzed:      {global_stats['total_message_types']}")
print(f"   Total messages analyzed:     {global_stats['total_messages_analyzed']}")
print(f"   Messages with checksum OK:   {global_stats['total_messages_ok']} ({global_stats['total_messages_ok']/global_stats['total_messages_analyzed']*100:.2f}%)" if global_stats['total_messages_analyzed'] > 0 else "N/A")
print(f"   Messages with WRONG checksum: {global_stats['total_messages_fail']} ({global_stats['total_messages_fail']/global_stats['total_messages_analyzed']*100:.2f}%)" if global_stats['total_messages_analyzed'] > 0 else "N/A")
print()

print("=" * 100)
print("📋 DETAIL BY MESSAGE TYPE:")
print("=" * 100)
print()

# Sort by success rate (from worst to best)
sorted_details = sorted(global_stats['details_per_message'], key=lambda x: x['success_rate'])

for detail in sorted_details:
    status_icon = "✅" if detail['success_rate'] == 100.0 else "⚠️" if detail['success_rate'] > 0 else "❌"
    print(f"{status_icon} {detail['message_id']} ({detail['message_name']}) - Bus {detail['bus']}")
    print(f"   Total: {detail['total']:6d} | OK: {detail['ok']:6d} ({detail['success_rate']:6.2f}%) | FAIL: {detail['fail']:6d} ({100-detail['success_rate']:6.2f}%)")
    print()

# Summary of messages with problems
messages_with_errors = [d for d in global_stats['details_per_message'] if d['fail'] > 0]
messages_perfect = [d for d in global_stats['details_per_message'] if d['success_rate'] == 100.0]

print("=" * 100)
print("🎯 SUMMARY:")
print("=" * 100)
print(f"✅ Messages with PERFECT checksums (100%):  {len(messages_perfect)}/{global_stats['total_message_types']}")
print(f"⚠️  Messages with AT LEAST ONE ERROR:       {len(messages_with_errors)}/{global_stats['total_message_types']}")
print()

if messages_with_errors:
    print("⚠️  MESSAGES WITH ERRORS:")
    for detail in sorted(messages_with_errors, key=lambda x: x['fail'], reverse=True):
        print(f"   - {detail['message_id']} ({detail['message_name']}) Bus {detail['bus']}: {detail['fail']} errors out of {detail['total']} ({100-detail['success_rate']:.2f}%)")

print("\n🎉 COMPLETED!")
# Out:
# ====================================================================================================
# 🏁 FINAL STATISTICS - COMPLETE SUMMARY
# ====================================================================================================
#
# 📊 OVERALL TOTALS:
#    Message types analyzed:      9
#    Total messages analyzed:     78709
#    Messages with checksum OK:   69080 (87.77%)
#    Messages with WRONG checksum: 9629 (12.23%)
#
# ====================================================================================================
# 📋 DETAIL BY MESSAGE TYPE:
# ====================================================================================================
#
# ❌ 0x3AD (Dyn_EasyMove) - Bus 0
#    Total:   9483 | OK:      0 (  0.00%) | FAIL:   9483 (100.00%)
#
# ❌ 0x3F2 (LANE_KEEP_ASSIST) - Bus 0
#    Total:    146 | OK:      0 (  0.00%) | FAIL:    146 (100.00%)
#
# ✅ 0x2B6 (HS2_DYN1_MDD_ETAT_2B6) - Bus 1
#    Total:   9448 | OK:   9448 (100.00%) | FAIL:      0 (  0.00%)
#
# ✅ 0x2F5 (STEERING) - Bus 0
#    Total:  18964 | OK:  18964 (100.00%) | FAIL:      0 (  0.00%)
#
# ✅ 0x2F6 (HS2_DYN_MDD_ETAT_2F6) - Bus 1
#    Total:   9447 | OK:   9447 (100.00%) | FAIL:      0 (  0.00%)
#
# ✅ 0x305 (STEERING_ALT) - Bus 0
#    Total:  18893 | OK:  18893 (100.00%) | FAIL:      0 (  0.00%)
#
# ✅ 0x38D (HS2_DYN_ABR_38D) - Bus 0
#    Total:   4741 | OK:   4741 (100.00%) | FAIL:      0 (  0.00%)
#
# ✅ 0x42D (NEW_MSG_42D) - Bus 0
#    Total:   3793 | OK:   3793 (100.00%) | FAIL:      0 (  0.00%)
#
# ✅ 0x452 (HS2_DAT_MDD_CMD_452) - Bus 1
#    Total:   3794 | OK:   3794 (100.00%) | FAIL:      0 (  0.00%)
#
# ====================================================================================================
# 🎯 SUMMARY:
# ====================================================================================================
# ✅ Messages with PERFECT checksums (100%):  7/9
# ⚠️  Messages with AT LEAST ONE ERROR:       2/9
#
# ⚠️  MESSAGES WITH ERRORS:
#    - 0x3AD (Dyn_EasyMove) Bus 0: 9483 errors out of 9483 (100.00%)
#    - 0x3F2 (LANE_KEEP_ASSIST) Bus 0: 146 errors out of 146 (100.00%)
#
# 🎉 COMPLETED!
